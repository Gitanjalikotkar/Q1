# %%
#OJT Assignment (25 Marks.)
#Q1. Data Visualization and Statistical Measures:
#For this question, you are required to analyse the iris dataset (iris.csv) using Python. 
#Perform allpossible data visualization techniques (histograms, scatter plots, box plots, etc.) on all numericalcolumns of the dataset.
#Additionally, calculate all possible statistical measures (mean, median,mode, standard deviation, etc.) for each numerical column.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Load the dataset
file = pd.read_csv(r"iris.csv")

# %%
# Display the first few rows of the dataset
print(file.head())
# Summary statistics
print("\nSummary Statistics:")
print(file.describe())
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa
#
# Summary Statistics:
#        Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# ...

# %%
# Data Visualization
# Histograms for numerical columns
file.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
# Box plots for numerical columns
plt.figure(figsize=(10, 8))
sns.boxplot(data=file)
plt.title("Box plots for Numerical Columns")
plt.show()

# %%
# Load the dataset
file = pd.read_csv(r"iris.csv")

# %%
# Extract numerical columns
numerical_columns = file .select_dtypes(include=['float64',
'int64'])
# Calculate mean for each numerical column
mean= numerical_columns.mean()
# Calculate median for each numerical column
median= numerical_columns.median()
# Calculate mode for each numerical column
mode= numerical_columns.mode().iloc[0]
# Calculate standard deviation for each numerical column
stddeviation= numerical_columns.std()

# %%
# Load the dataset
file= pd.read_csv(r"iris.csv")
# Extract numerical columns
numerical_columns = file.select_dtypes(include=['float64',
'int64'])
# Calculate mean for each numerical column
mean= numerical_columns.mean()
# Calculate median for each numerical column
median= numerical_columns.median()
# Calculate mode for each numerical column
mode= numerical_columns.mode().iloc[0]
# Calculate standard deviation for each numerical column
stddeviation= numerical_columns.std()

# %%
# Print the results
print("Mean:")
print(mean)
print("\nMedian:")
print(median)
print("\nMode:")
print(mode)
print("\nStandard Deviation:")
print(stddeviation)
# Out:
# Mean:
# Unnamed: 0      75.500000
# Sepal.Length     5.843333
# Sepal.Width      3.057333
# Petal.Length     3.758000
# Petal.Width      1.199333
# dtype: float64
#
# Median:
# Unnamed: 0      75.50
# Sepal.Length     5.80
# Sepal.Width      3.00
# Petal.Length     4.35
# Petal.Width      1.30
# dtype: float64
#
# Mode:
# Unnamed: 0      1.0
# Sepal.Length    5.0
# Sepal.Width     3.0
# Petal.Length    1.4
# Petal.Width     0.2
# Name: 0, dtype: float64
#
# Standard Deviation:
# Unnamed: 0      43.445368
# Sepal.Length     0.828066
# Sepal.Width      0.435866
# Petal.Length     1.765298
# Petal.Width      0.762238
# dtype: float64
